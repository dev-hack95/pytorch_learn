# %%
import os
import torch
import pathlib
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snsZ
from torch import nn
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

# %%
n_samples = 1000

x, y = make_circles(n_samples, noise=0.03, random_state = 42)

# %%
len(x), len(y)
# Out:
# (1000, 1000)

# %%
x[:1]
# Out:
# array([[0.75424625, 0.23148074]])

# %%
circles = pd.DataFrame({"X1": x[:, 0],
                       "X2": x[:, 1],
                       "label": y})

# %%
circles.head()
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0

# %%
plt.figure(figsize=(15, 8))
plt.scatter(x=x[:, 0], y = x[:, 1], c = y , cmap = plt.cm.brg)

# %%
class TrainTestSplit:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def NumpyToTensor(self) -> tuple[torch.Tensor, torch.Tensor]:
        x = torch.from_numpy(self.x).type(torch.float)
        y = torch.from_numpy(self.y).type(torch.float)
        return x, y
        
    def SplitData(self) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
        x_tensor, y_tensor = self.NumpyToTensor()
        x_train, x_test, y_train, y_test = train_test_split(x_tensor, y_tensor, test_size=0.3, random_state=42)
        return x_train, x_test, y_train, y_test

# %%
data_1 = TrainTestSplit(x, y)

# %%
x_train, x_test, y_train, y_test = data_1.SplitData()

# %%
x_train[:1]
# Out:
# tensor([[-0.9342, -0.2457]])

# %%
x_test[:1]
# Out:
# tensor([[-0.3752,  0.6827]])

# %%
y_train[:1]
# Out:
# tensor([0.])

# %%
y_test[:1]
# Out:
# tensor([1.])

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
x_train.shape, y_train.shape
# Out:
# (torch.Size([700, 2]), torch.Size([700]))

# %%
class CircleModelV1(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=5) # Takes in two features and upscales to 5 (Inner layers with 5 neurons)
        self.layer_2 = nn.Linear(in_features=5, out_features=1) # Take 5 features of from previous layers and return single feature

    def forward(self, x):
        return self.layer_2(self.layer_1(x)) # x -> layer_1 ---> layer_2 -> output

# %%
model_1 = CircleModelV1().to(device)
model_1 # 2 ----> 5 ----> 1
# Out:
# CircleModelV1(
#   (layer_1): Linear(in_features=2, out_features=5, bias=True)
#   (layer_2): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
list(model_1.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0040,  0.3851],
#          [ 0.4529,  0.4476],
#          [-0.5572,  0.4411],
#          [ 0.0087,  0.1586],
#          [-0.6579,  0.1077]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.1315,  0.1448,  0.1888,  0.4053, -0.5657], requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0956, -0.1813,  0.1754,  0.3170,  0.4173]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.2036], requires_grad=True)]

# %%
model_1.state_dict()
# Out:
# OrderedDict([('layer_1.weight',
#               tensor([[ 0.0040,  0.3851],
#                       [ 0.4529,  0.4476],
#                       [-0.5572,  0.4411],
#                       [ 0.0087,  0.1586],
#                       [-0.6579,  0.1077]])),
#              ('layer_1.bias',
#               tensor([-0.1315,  0.1448,  0.1888,  0.4053, -0.5657])),
#              ('layer_2.weight',
#               tensor([[ 0.0956, -0.1813,  0.1754,  0.3170,  0.4173]])),
#              ('layer_2.bias', tensor([-0.2036]))])

# %%
class TrainModel:
    def __init__(self, model, x_train, x_test, y_train, y_test, epochs=50, lr=0.01):
        self.model = model
        self.x_train = x_train
        self.y_train = y_train
        self.x_test = x_test
        self.y_test = y_test
        self.epochs = epochs

        self.loss_fn = nn.BCEWithLogitsLoss()
        self.optimizer = torch.optim.SGD(params=self.model.parameters(), lr=lr)

    def Accuracy(self, y_true, y_pred):
        accuracy = torch.eq(y_true, y_pred).sum().item()
        acc = (accuracy / len(y_pred)) * 100
        return acc
        
    def Train(self):
        # Set random seed
        torch.manual_seed(42)
        for epoch in range(1, self.epochs + 1):
            self.model.train()
            y_logits = self.model(self.x_train).squeeze()
            y_pred = torch.round(torch.sigmoid(y_logits)) # Turn logits -> pred probs -> pred lables
            # loss = self.loss_fn(torch.sigmod(y_logits), self.y_train) # For nn.BCEloss 
            loss = self.loss_fn(y_logits, self.y_train)
            accuracy = self.Accuracy(self.y_train, y_pred)
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            if epoch % 5 == 0:
                self.model.eval()
                with torch.inference_mode():
                    test_logits = self.model(x_test).squeeze()
                    test_pred = torch.round(torch.sigmoid(test_logits))
                    test_loss = self.loss_fn(test_logits, y_test)
                    test_acc = self.Accuracy(y_test, test_pred)
                    print(f"Epoch: {epoch} | test_loss : {test_loss} | test_acc: {round(test_acc, 2)}")

# %%
model_1 = CircleModelV1()

# %%
train_1 = TrainModel(model=model_1, x_train=x_train, x_test=x_test, y_train=y_train, y_test=y_test, epochs=200, lr=0.01)

# %%
train_1.Train()
# Out:
# Epoch: 5 | test_loss : 0.7043712735176086 | test_acc: 49.666666666666664
# Epoch: 10 | test_loss : 0.7041401863098145 | test_acc: 49.0
# Epoch: 15 | test_loss : 0.7039233446121216 | test_acc: 49.333333333333336
# Epoch: 20 | test_loss : 0.7037199139595032 | test_acc: 49.333333333333336
# Epoch: 25 | test_loss : 0.7035288214683533 | test_acc: 49.0
# Epoch: 30 | test_loss : 0.7033491134643555 | test_acc: 49.333333333333336
# Epoch: 35 | test_loss : 0.7031802535057068 | test_acc: 49.333333333333336
# Epoch: 40 | test_loss : 0.7030210494995117 | test_acc: 49.333333333333336
# Epoch: 45 | test_loss : 0.7028712034225464 | test_acc: 49.666666666666664
# Epoch: 50 | test_loss : 0.7027298808097839 | test_acc: 49.666666666666664
# Epoch: 55 | test_loss : 0.7025964260101318 | test_acc: 49.666666666666664
# Epoch: 60 | test_loss : 0.7024703025817871 | test_acc: 49.666666666666664
# Epoch: 65 | test_loss : 0.7023510932922363 | test_acc: 50.0
# ...

# %%
x[:5], y[:5]
# Out:
# (array([[ 0.75424625,  0.23148074],
#         [-0.75615888,  0.15325888],
#         [-0.81539193,  0.17328203],
#         [-0.39373073,  0.69288277],
#         [ 0.44220765, -0.89672343]]),
#  array([1, 1, 1, 1, 0], dtype=int64))

# %%
def plot_decision_boundary(model: nn.Module, x: torch.Tensor, y: torch.Tensor):
    """
    plot_decision_boundary(model: torch model | x: Tensor | y: Tensor)
    """
    x_min, x_max = x[:, 0].min() - 0.1, x[:, 0].max() + 0.1
    y_min, y_max = x[:, 1].min() - 0.1, x[:, 1].max() + 0.1
    x1, y1 = np.meshgrid(np.linspace(x_min, x_max, 101), np.linspace(y_min, y_max, 101)) # shape of x1 and y1 -> 101 X 101

    x_to_predict = torch.from_numpy(np.column_stack((x1.ravel(), y1.ravel()))).float() # ravel -> ([1, 2, 3], [4, 5, 6]) -------> ([1, 2, 3, 4, 5, 6])
    # column stack = [[x1, y1]]
    
    model.eval()
    with torch.inference_mode():
        y_logits = model(x_to_predict)

    if len(torch.unique(y)) > 2:
        y_pred = torch.softmax(y_logits, dim=1).argmax(dim=1)  # mutli-class
    else:
        y_pred = torch.round(torch.sigmoid(y_logits))  # binary

    y_pred = y_pred.reshape(x1.shape).detach().numpy()
    plt.contourf(x1, y1, y_pred)
    plt.scatter(x[:, 0], x[:, 1], c=y)
    plt.xlim(x1.min(), x1.max())
    plt.ylim(y1.min(), y1.max())
    plt.show()

# %%
plot_decision_boundary(model=model_1, x=x_train, y=y_train)

# %%
plot_decision_boundary(model=model_1, x=x_test, y=y_test)

# %%
class CirclesModelV2(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.layer_1 = nn.Linear(in_features=2, out_features=32)
        self.layer_2 = nn.Linear(in_features=32, out_features=32)
        self.layer_3 = nn.Linear(in_features=32, out_features=1)
        self.relu = nn.ReLU()

    def forward(self, x):
       return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

# %%
model_2 = CirclesModelV2()

# %%
train_2 = TrainModel(model=model_2, x_train=x_train, x_test=x_test, y_train=y_train, y_test=y_test, epochs=200, lr=0.01)

# %%
train_2.Train()
# Out:
# Epoch: 5 | test_loss : 0.6935676336288452 | test_acc: 48.0
# Epoch: 10 | test_loss : 0.6935429573059082 | test_acc: 48.0
# Epoch: 15 | test_loss : 0.6935179829597473 | test_acc: 48.0
# Epoch: 20 | test_loss : 0.693492591381073 | test_acc: 48.0
# Epoch: 25 | test_loss : 0.6934680938720703 | test_acc: 48.0
# Epoch: 30 | test_loss : 0.693443775177002 | test_acc: 48.0
# Epoch: 35 | test_loss : 0.6934186816215515 | test_acc: 48.0
# Epoch: 40 | test_loss : 0.6933938264846802 | test_acc: 48.0
# Epoch: 45 | test_loss : 0.6933683753013611 | test_acc: 48.0
# Epoch: 50 | test_loss : 0.6933434009552002 | test_acc: 48.0
# Epoch: 55 | test_loss : 0.6933197975158691 | test_acc: 48.0
# Epoch: 60 | test_loss : 0.6932979226112366 | test_acc: 48.0
# Epoch: 65 | test_loss : 0.6932766437530518 | test_acc: 48.0
# Epoch: 70 | test_loss : 0.6932560205459595 | test_acc: 48.0
# Epoch: 75 | test_loss : 0.6932370662689209 | test_acc: 48.0
# Epoch: 80 | test_loss : 0.6932187676429749 | test_acc: 48.0
# ...
